# %%
import pandas as pd
import numpy as np
import ast
from tqdm import tqdm
import sys
import time

from flashgeotext.geotext import GeoText
from geopy.geocoders import Nominatim

# %%
articles = pd.read_csv('data/characteristics_labelled.csv', index_col=0)

# %%
articles.authors = articles.authors.apply(lambda x: ast.literal_eval(x) if type(x) == str else x)
articles.author_affils = articles.author_affils.apply(lambda x: ast.literal_eval(x) if type(x) == str else x)
articles.keywords = articles.keywords.apply(lambda x: ast.literal_eval(x) if type(x) == str else x)
articles.references_pmids = articles.references_pmids.apply(lambda x: ast.literal_eval(x) if type(x) == str else x)
articles.mesh_terms = articles.mesh_terms.apply(lambda x: ast.literal_eval(x) if type(x) == str else x)

# %%
articles['affil_countries'] = np.nan
articles['affil_countries'] = articles['affil_countries'].astype(object)
articles['affil_countries_unique'] = np.nan
articles['affil_countries_unique'] = articles['affil_countries'].astype(object)
articles['affil_first_country'] = np.nan
articles['affil_last_country'] = np.nan

# %%
def find_affil_countries(affils: list, retry_count = 5):
    
    geolocator = Nominatim(user_agent='health_ai_scraper')
    geotext = GeoText()
    
    if affils == affils: # Check to make sure not NaN
        country_list = []
        location = None
        
        last_affil = None
        last_country = None
        
        try_count = 0
    
        for affil in affils:
            if affil == last_affil: # Check to see if we've seen this before and take a shortcut if we have
                country_list = country_list + last_country

            else:
                while try_count < retry_count:
                    try:
                        last_affil = affil # Set that we've examined this affil
                
                        countries = [*geotext.extract(input_text=affil, span_info=True)['countries'].keys()] # Look for countries
                
                        if (len(countries) == 0): # If we dont find a country look harder
                            cities = [*geotext.extract(input_text=affil, span_info=True)['cities'].keys()]
                            if len(cities) > 0:
                                location = geolocator.geocode(cities[-1])
                            else:
                                location = geolocator.geocode(' '.join(affil.split(" ")[-2:]))
                                if location == None:
                                    location = geolocator.geocode(affil)
                                    if location == None:
                                        tqdm.write("Can't find a country for:")
                                        tqdm.write(affil)
                                        country_list = country_list + [np.nan]
                                        last_country = [np.nan]
                            
                        else: # If we do find a country then att it to the list and set the last_country variable
                            country_list = country_list + countries
                            last_country = countries
        
                        if location != None: # If we found an address using the other search techniques
                            countries = [*geotext.extract(input_text=location.address, span_info=True)['countries'].keys()]
                            country_list = country_list + countries
                            last_country = countries
                            
                        break
                            
                    except:
                        try_count += 1
                        tqdm.write(f"Error parsing {affil}, trying again for a maximum of 5 times.")
                        
    else: # If the affil is NaN then make the country list NaN
        country_list = [np.nan]
        
    unique_countries = list(set(country_list))
    first_affil_country = country_list[0]
    last_affil_country = country_list[-1]    
        
    return country_list, unique_countries, first_affil_country, last_affil_country

# %%
def parse_affil_countries(df, max_consecutive_failures = 5, filter_column = 'include'):
    
    consecutive_failures = 0
    
    country_df = df.copy()
    
    country_df['affil_countries'] = np.nan
    country_df['affil_countries_unique'] = np.nan
    country_df['affil_countries_first'] = np.nan
    country_df['affil_countries_last'] = np.nan
    
    with tqdm(total=country_df.shape[0], file=sys.stdout) as pbar:
        for row in country_df[country_df[filter_column] == 1].itertuples():

            try:
                affils = row.author_affils
    
                country_list, unique_countries, first_affil_country, last_affil_country = find_affil_countries(affils)
    
                country_df.loc[row.Index, 'affil_countries'] = str(country_list)
                country_df.loc[row.Index, 'affil_countries_unique'] = str(list(set(country_list)))
                country_df.loc[row.Index, 'affil_countries_first'] = country_list[0]
                country_df.loc[row.Index, 'affil_countries_last'] = country_list[-1]
            
                consecutive_failures = 0
        
            except Exception as e:
                tqdm.write(e)
                consecutive_failures += 1
                if consecutive_failures >=  max_consecutive_failures:
                    tqdm.write("Failed too many in a row, something is broken, stopping and returning possibly partially labelled DF...")
                    break
                
            pbar.update(1)
            
    country_df.replace("[nan]", np.nan, inplace=True)
            
    return country_df

# %%
consecutive_failures = 0

with tqdm(total=articles.shape[0], file=sys.stdout) as pbar:
    for row in articles.itertuples():

        try:
            affils = row.author_affils
    
            country_list, unique_countries, first_affil_country, last_affil_country = find_affil_countries(affils)
    
            articles.loc[row.Index, 'affil_countries'] = str(country_list)
            articles.loc[row.Index, 'affil_countries_unique'] = str(list(set(country_list)))
            articles.loc[row.Index, 'affil_first_country'] = country_list[0]
            articles.loc[row.Index, 'affil_last_country'] = country_list[-1]
            
            consecutive_failures = 0
        
        except:
            consecutive_failures += 1
            if consecutive_failures > 5:
                print("Failed too many in a row, something is broken, stopping...")
                break
            time.sleep(1)
                
        pbar.update(1)
# Out:
# Can't find a country for:
# Cosmo Artificial Intelligence-AI Ltd.
# Can't find a country for:
# Ming Hsieh Department of Electrical and Computer Engineering (R.M.L., A.A.J.).
# Can't find a country for:
# Departments of Radiology (P.E.K.).
# Can't find a country for:
# Ming Hsieh Department of Electrical and Computer Engineering (R.M.L., A.A.J.) ajoshi@usc.edu.
# Can't find a country for:
# See Acknowledgements, .
# Can't find a country for:
# R, EarlyDiagnostics Inc.
# Can't find a country for:
# Bioinformatics, EarlyDiagnostics Inc.
# Can't find a country for:
# Departments of Clinical Epidemiology and Biostatistics (S.Y.P.).
# Can't find a country for:
# Quick Step Analytics LLC.
# Can't find a country for:
# Nightingale Health Plc.
# Can't find a country for:
# Nightingale Health Plc.
# Can't find a country for:
# Hawaii Pathologists' Laboratory, LLP.
# Can't find a country for:
# Center for Cognitive and Memory Disorders.
# Can't find a country for:
# Osaka Prefectural Nakakawachi Medical Center of Acute Medicine.
# Can't find a country for:
# Google Health. Electronic address: agroy@google.com.
# Can't find a country for:
# Google Research, Brain Team. Electronic address: jjren@google.com.
# Can't find a country for:
# Google Research, Brain Team.
# Can't find a country for:
# Google Research, Brain Team. Electronic address: balajiln@google.com.
# Can't find a country for:
# Google Health. Electronic address: jimwinkens@google.com.
# Can't find a country for:
# PathomIQ.
# Can't find a country for:
# PathomIQ.
# Can't find a country for:
# Independent Researcher.
# Can't find a country for:
# Department of Genetics and Genomic Sciences.
# Can't find a country for:
# Department of Genetics and Genomic Sciences.
# Can't find a country for:
# Department of Genetics and Genomic Sciences.
# Can't find a country for:
# Acute Care Surgery and General Surgery, Hamad Medical Corporation, Qatar.
# Can't find a country for:
# Clinical Medicine and Surgery (R.C.) renato.cuocolo@unina.it.
# Can't find a country for:
# Electrical Engineering and Information Technology (G.P., M.Q.).
# Can't find a country for:
# 2Departments of Neurology and Neurosurgery, and.
# Can't find a country for:
# 2Departments of Neurology and Neurosurgery, and.
# Can't find a country for:
# Division of Biostatistics, and.
# Can't find a country for:
# Department of Biomedical Statistics and Bioinformatics, and.
# Can't find a country for:
# Department of Biomedical EngineeringCase Western Reserve UniversityClevelandOH44106USA.
# Can't find a country for:
# The Tony and Leona Campane Center for Excellence in Image-Guided Surgery and Advancing Imaging ResearchCleveland Clinic Cole Eye InstituteClevelandOH44106USA.
# Can't find a country for:
# Department of Biomedical EngineeringCase Western Reserve UniversityClevelandOH44106USA.
# Can't find a country for:
# The Tony and Leona Campane Center for Excellence in Image-Guided Surgery and Advancing Imaging ResearchCleveland Clinic Cole Eye InstituteClevelandOH44106USA.
# Can't find a country for:
# Department of Biomedical EngineeringCase Western Reserve UniversityClevelandOH44106USA.
# Can't find a country for:
# The Tony and Leona Campane Center for Excellence in Image-Guided Surgery and Advancing Imaging ResearchCleveland Clinic Cole Eye InstituteClevelandOH44106USA.
# Can't find a country for:
# Athinoula A. Martinos Center for Biomedical Imaging, Massachusetts General Hospital and Harvard Medical School, Charlestown, Massachusetts; ccatana@mgh.harvard.edu.
# Can't find a country for:
# Departments of Neurosurgery (L.M.P., G.A.G.).
# Can't find a country for:
# Neurology (P.G.F.).
# Can't find a country for:
# Departments of Neurosurgery (L.M.P., G.A.G.).
# Can't find a country for:
# Department of Surgical Gastroenterology and Transplantation, Rigshospitalet; Center for Surgical Translational and Artificial Intelligence Research, Rigshospitalet.
# Can't find a country for:
# Department of Surgical Gastroenterology and Transplantation, Rigshospitalet; Center for Surgical Translational and Artificial Intelligence Research, Rigshospitalet.
# Can't find a country for:
# Department of Statistics and Applied Probability (A.H.T.).
# Can't find a country for:
# DuPage Medical Group, Radiology. Electronic address: ayis@ayis.org.
# Can't find a country for:
# DuPage Medical Group, Radiology.
# Can't find a country for:
# DuPage Medical Group, Radiology.
# Can't find a country for:
# Radiology Department, Hospital Universitarioy Polite'cnico La Fe and Biomedical Imaging Research Group (GIBI230).
# Can't find a country for:
# CardioIntelligence Inc.
# Can't find a country for:
# Gastroenterology Outpatient Clinic, Altötting.
# Can't find a country for:
# Department of Mathematical & Statistical Sciences.
# Can't find a country for:
# Department of Mathematical & Statistical Sciences.
# Can't find a country for:
# Department of Data Systems, 3D Medicines Inc.
# Can't find a country for:
# Department of Data Systems, 3D Medicines Inc.
# Can't find a country for:
# Department of Pathology, 3D Medicines Inc.
# Can't find a country for:
# Department of Data Systems, 3D Medicines Inc.
# Can't find a country for:
# Department of Computer Science and EngineeringUniversity of RajshahiRajshahi6205Bangladesh.
# Can't find a country for:
# Department of Mathematics and StatisticsImam Muhammad Ibn Saud Islamic UniversityRiyadh13318Saudi Arabia.
# Can't find a country for:
# Bone Biology DivisionGarvan Institute of Medical ResearchDarlinghurstNSW2010Australia.
# Can't find a country for:
# WHO Collaborating Centre of eHealth, School of Public Health and Community MedicineUniversity of New South WalesSydneyNSW2052Australia.
# Can't find a country for:
# Departments of1Neurosurgery and.
# Can't find a country for:
# Departments of1Neurosurgery and.
# Can't find a country for:
# Departments of1Neurosurgery and.
# Can't find a country for:
# Lunit Incorporated.
# Can't find a country for:
# Google Health via Advanced Clinical.
# Can't find a country for:
# Google Health via Advanced Clinical.
# Can't find a country for:
# Department of Epidemiology and Biostatistics.
# Can't find a country for:
# Data used in preparation of this article were obtained from the Alzheimer's Disease Neuroimaging Initiative (ADNI) database (adni.loni.usc.edu). As such, the investigators within the ADNI contributed to the design and implementation of ADNI and/or provided data but did not participate in analysis or writing of this report. A complete listing of ADNI investigators can be found at: http://adni.loni.usc.edu/wp-content/uploads/how_to_apply/ADNI_Acknowledgement_List.pdf.
# Can't find a country for:
# Data used in the preparation of this article was obtained from the Australian Imaging Biomarkers and Lifestyle Flagship Study of Ageing (AIBL) funded by the Commonwealth Scientific and Industrial Research Organisation (CSIRO) which was made available at the ADNI database. The AIBL researchers contributed data but did not participate in analysis or writing of this report. AIBL researchers are listed at www.aibl.csiro.au.
# Can't find a country for:
# Department of Electronic Science and TechnologyUniversity of Science and Technology of ChinaHefei230027China.
# Can't find a country for:
# Department of ElectrocardiogramThe First Affiliated Hospital of USTC, Division of Life Sciences and MedicineUniversity of Science and Technology of ChinaHefei230001China.
# Can't find a country for:
# Department of Electronic Science and TechnologyUniversity of Science and Technology of ChinaHefei230027China.
# Can't find a country for:
# Department of Electronic Engineering and Information ScienceUniversity of Science and Technology of ChinaHefei230027China.
# Can't find a country for:
# Respiratory Unit and Cystic Fibrosis Adult Center, Fondazione IRCCS Ca'Granda Ospedale Maggiore Policlinico.
# Can't find a country for:
# Respiratory Unit and Cystic Fibrosis Adult Center, Fondazione IRCCS Ca'Granda Ospedale Maggiore Policlinico.
# Can't find a country for:
# Respiratory Unit and Cystic Fibrosis Adult Center, Fondazione IRCCS Ca'Granda Ospedale Maggiore Policlinico.
# Can't find a country for:
# SimulaMet0167OsloNorway.
# Can't find a country for:
# SimulaMet0167OsloNorway.
# Can't find a country for:
# SimulaMet0167OsloNorway.
# Can't find a country for:
# Medcurio.
# Can't find a country for:
# Department of Ophthalmology, Casey Eye Institute and campbelp@ohsu.edu.
# Can't find a country for:
# Division of Epidemiology, and.
# Can't find a country for:
# Division of Epidemiology, and.
# Can't find a country for:
# Department of Immunobiology.
# Can't find a country for:
# Department of Orthopedics Trauma and Hand Surgery.
# Can't find a country for:
# Department of Orthopedics Trauma and Hand Surgery.
# Can't find a country for:
# Heart and Vascular Center, Evangelical Hospital, Lewisburg, PA (J.M.P.).
# Can't find a country for:
# Department of Computer Science and EngineeringUniversity of RajshahiRajshahi6205Bangladesh.
# Can't find a country for:
# Faculty of Medicine, School of PsychiatryUniversity of New South WalesSydneyNSW2052Australia.
# Can't find a country for:
# Department of Mathematics and StatisticsImam Mohammad Ibn Saud Islamic UniversityRiyadh11432Saudi Arabia.
# Can't find a country for:
# Garvan Institute of Medical ResearchDarlinghurstNSW2010Australia.
# Can't find a country for:
# Faculty of Medicine, School of PsychiatryUniversity of New South WalesSydneyNSW2052Australia.
# Can't find a country for:
# Department of Radiology (K.H., H.K., S.S.A., Y.W.P., S.-K.L.), Research Institute of Radiological Sciences, Center for Clinical Imaging Data Science sungsoo@yuhs.ac.
# Can't find a country for:
# Department of Neurosurgery (J.H.C.).
# Can't find a country for:
# See Acknowledgments, .
# Can't find a country for:
# Supernus Pharmaceuticals, Inc.
# Can't find a country for:
# Supernus Pharmaceuticals, Inc.. Electronic address: anasser@supernus.com.
# Can't find a country for:
# Research and Practical Clinical Center for Diagnostics and Telemedicine Technologies.
# Can't find a country for:
# Research and Practical Clinical Center for Diagnostics and Telemedicine Technologies.
# Can't find a country for:
# Skolkovo Institute of Science and Technology; Kharkevich Institute for Information Transmission Problems.
# Can't find a country for:
# Research and Practical Clinical Center for Diagnostics and Telemedicine Technologies.
# Can't find a country for:
# Research and Practical Clinical Center for Diagnostics and Telemedicine Technologies.
# Can't find a country for:
# Tri-Institutional Center for Translational Research in Neuroimaging and Data Science (TReNDS).
# Can't find a country for:
# Department of Computer ScienceSwansea UniversitySwanseaSA1 8ENU.K.
# Can't find a country for:
# Department of Computer ScienceSwansea UniversitySwanseaSA1 8ENU.K.
# Can't find a country for:
# School of Biomedical Informatics.
# Can't find a country for:
# School of Biomedical Informatics.
# Can't find a country for:
# School of Biomedical Informatics.
# Can't find a country for:
# Department of Radiology, Shamir Medical Center, Zerifin.
# Can't find a country for:
# Department of Radiology, Shamir Medical Center, Zerifin.
# Can't find a country for:
# Department of Radiology, Shamir Medical Center, Zerifin.
# Can't find a country for:
# Neurosurgery (J.S.W., S.S.P.).
# Can't find a country for:
# Pathology (G.N.F.).
# Can't find a country for:
# Neuroradiology (J.H., D.S.) Dawid.Schellingerhout@mdanderson.org.
# Can't find a country for:
# Department of Information EngineeringUniversità Politecnica delle Marche60131AnconaItaly.
# Can't find a country for:
# Federazione Italiana Medici di Medicina Generale (FIMMG)00144RomeItaly.
# Can't find a country for:
# Department of Information EngineeringUniversità Politecnica delle Marche60131AnconaItaly.
# Can't find a country for:
# Département de génie logiciel et des TI, École de technologie supérieure.
# Can't find a country for:
# MondoBrain.
# Can't find a country for:
# Richard and Loan Hill Department of BioengineeringUniversity of Illinois at ChicagoChicagoIL60607USA.
# Can't find a country for:
# Department of MedicineUniversity of Illinois at ChicagoChicagoIL60612USA.
# Can't find a country for:
# Richard and Loan Hill Department of BioengineeringUniversity of Illinois at ChicagoChicagoIL60607USA.
# Can't find a country for:
# Shared first authors.
# Can't find a country for:
# Department of Radiology, Massachusetts General Hospital and Harvard Medical School. Electronic address: Cai.Wenli@mgh.harvard.edu.
# Can't find a country for:
# Department of Surgery, Donald and Barbara Zucker School of Medicine at Hofstra/Northwell, Manhasset, NY; Divisions of Vascular and Endovascular Surgery, Donald and Barbara Zucker School of Medicine at Hofstra/Northwell, Manhasset, NY. Electronic address: fmussa@northwell.edu.
# Can't find a country for:
# Indian Institute of Technology HyderabadHyderabad502205India.
# Can't find a country for:
# RMIT UniversityMelbourneVIC3001Australia.
# Can't find a country for:
# Indian Institute of Technology HyderabadHyderabad502205India.
# Can't find a country for:
# RMIT UniversityMelbourneVIC3001Australia.
# Can't find a country for:
# 4Renishaw plc, Spectroscopy Products Division, Gloucestershire.
# Can't find a country for:
# Department of Statistics and Actuarial Sciences.
# Can't find a country for:
# 3Neurosurgery.
# Can't find a country for:
# 3Neurosurgery.
# Can't find a country for:
# Department of Radiology (W.B., J.S., M.P.L., K.W.Y.).
# Can't find a country for:
# Electrical Engineering (E.H.L.).
# Can't find a country for:
# Radiology (E.T., M.I.).
# Can't find a country for:
# Department of Radiology (W.B., J.S., M.P.L., K.W.Y.).
# Can't find a country for:
# and Neurosurgery (M.D.T.).
# Can't find a country for:
# Department of Radiology (W.B., J.S., M.P.L., K.W.Y.) kyeom@stanford.edu.
# Can't find a country for:
# Department of Computer ScienceGonzaga UniversitySpokaneWA99258USA.
# Can't find a country for:
# St. Luke's Rehabilitation InstituteSpokaneWA99202USA.
# Can't find a country for:
# School of Electrical Engineering and Computer ScienceWashington State UniversityPullmanWA99164USA.
# Can't find a country for:
# Department of Cardiovascular and Thoracic Surgery, Donald and Barbara Zucker School of Medicine at Hofstra/Northwell, Manhasset, NY. Electronic address: plee15@northwell.edu.
# Can't find a country for:
# Departments of Biostatistics.
# Can't find a country for:
# Department of Cardiovascular and Thoracic Surgery, Donald and Barbara Zucker School of Medicine at Hofstra/Northwell, Manhasset, NY. Electronic address: plee15@northwell.edu.
# Can't find a country for:
# Departments of Neurology (L.Y.).
# Can't find a country for:
# School of Computing and Electrical EngineeringIndian Institute of Technology MandiMandi175005India.
# Can't find a country for:
# Genome Profiling, LLC.
# Can't find a country for:
# Department of Preventive MedicineFeinberg School of MedicineNorthwestern UniversityChicagoIL60611USA.
# Can't find a country for:
# Institute of Statistics, National Chiao Tung UniversityHsinchu30010Taiwan.
# Can't find a country for:
# Department of Paediatric Gastroenterology.
# Can't find a country for:
# Department of Paediatric Gastroenterology.
# Can't find a country for:
# Radiology (J.H.).
# Can't find a country for:
# Neurology (S.V.).
# Can't find a country for:
# 1National Pilot School of SoftwareYunnan UniversityKunming650091China.
# Can't find a country for:
# 2School of Information Science and EngineeringYunnan UniversityKunming650091China.
# Can't find a country for:
# Maharaja Agrasen Institute of TechnologyNew Delhi110086India.
# Can't find a country for:
# Artificial Intelligence DepartmentResearch Center for AI and IoTNear East University99138MersinTurkey.
# Can't find a country for:
# 2FET - Computer Science and Creative TechnologiesUniversity of the West of EnglandBristolBS16 1QYU.K.
# Can't find a country for:
# 3Department of Computer Information SystemsCollege of Computer Science and Information TechnologyImam Abdulrahman Bin Faisal UniversityDammam34212Saudi Arabia.
# Can't find a country for:
# Department of Biostatistics, and.
# Can't find a country for:
# Facultad de Ingeniería, Universidad Panamericana; lmartine@up.edu.mx.
# Can't find a country for:
# 1Department of Electrical and Computer EngineeringUniversity of Western OntarioLondonONN6A 3K7Canada.
# Can't find a country for:
# 6School of Biomedical EngineeringUniversity of Western OntarioLondonONN6A 3K7Canada.
# Can't find a country for:
# 1Department of Electrical and Computer EngineeringUniversity of Western OntarioLondonONN6A 3K7Canada.
# Can't find a country for:
# 1Department of EngineeringFerrara University44122FerraraItaly.
# Can't find a country for:
# 2MIST E-R40129BolognaItaly.
# Can't find a country for:
# 3Tecnoideal s.r.l.41037MirandolaItaly.
# Can't find a country for:
# 2MIST E-R40129BolognaItaly.
# Can't find a country for:
# 4Medica s.p.a41036MedollaItaly.
# Can't find a country for:
# 2MIST E-R40129BolognaItaly.
# Can't find a country for:
# 1Department of EngineeringFerrara University44122FerraraItaly.
# Can't find a country for:
# Ophthalmology, OHSU.
# Can't find a country for:
# Ophthalmology, OHSU.
# Can't find a country for:
# Department of Health Outcomes and Biomedical Informatics.
# Can't find a country for:
# Department of Health Outcomes and Biomedical Informatics.
# Can't find a country for:
# Key Laboratory of Nuclear Physics and Ion-Beam Application (MOE).
# Can't find a country for:
# Department of Radiology. Electronic address: jsh0836@126.com.
# Can't find a country for:
# 1Department of Electrical EngineeringIndian Institute of Technology HyderabadHyderabad502205India.
# Can't find a country for:
# 2imec3001LeuvenBelgium.
# Can't find a country for:
# 1Department of Electrical EngineeringIndian Institute of Technology HyderabadHyderabad502205India.
# Can't find a country for:
# Division of Cardiology, Department of Medicine (D.R.O., J.C., S.J., K.C.W.).
# Can't find a country for:
# Division of Cardiology, Department of Medicine (D.R.O., J.C., S.J., K.C.W.).
# Can't find a country for:
# Division of Cardiology, Department of Medicine (D.R.O., J.C., S.J., K.C.W.).
# Can't find a country for:
# Division of Cardiology, Department of Medicine (D.R.O., J.C., S.J., K.C.W.).
# Can't find a country for:
# 1Beirut Research and Innovation CenterBeirut2052 6703Lebanon.
# Can't find a country for:
# 1Beirut Research and Innovation CenterBeirut2052 6703Lebanon.
# Can't find a country for:
# Department of Radiology, Stony Brook School of Medicine, Stony Brook, NY. Electronic address: tim.duong@stonybrookmedicine.edu.
# Can't find a country for:
# Medical & Imaging Informatics.
# Can't find a country for:
# 1Weldon School of Biomedical EngineeringPurdue UniversityWest LafayetteIN47907USA.
# Can't find a country for:
# Community Pharmacist.
# Can't find a country for:
# Embedded Systems and Artificial Intelligence Group, Universidad CEU Cardenal Herrera; juaparal@uchceu.es.
# Can't find a country for:
# 2School of Computing Sciences and Computer EngineeringUniversity of Southern MississippiLong BeachMS39560USA.
# Can't find a country for:
# 3College of ComputingMichigan Technological UniversityHoughtonMI49931USA.
# Can't find a country for:
# ...
# Error parsing Department of Cardiology (A.C., M.L.L., J.D., K.N.)., trying again for a maximum of 5 times.
# Error parsing Department of Cardiology (A.C., M.L.L., J.D., K.N.)., trying again for a maximum of 5 times.
# Can't find a country for:
# Department of Radiology (D.H.Y.).
# Error parsing Department of Cardiology (A.C., M.L.L., J.D., K.N.)., trying again for a maximum of 5 times.
# Error parsing Department of Cardiology (A.C., M.L.L., J.D., K.N.)., trying again for a maximum of 5 times.
# Can't find a country for:
# Department of Biostatistics.
# Can't find a country for:
# Department of Imaging Physics.
# Can't find a country for:
# Department of Hematopathology, and.
# Can't find a country for:
# State Key Laboratory of Fluid Power and Mechatronic Systems, College of Mechanical EngineeringZhejiang UniversityHangzhou310058China.
# Can't find a country for:
# ABB Corporate Research721 78VästeråsSweden.
# Can't find a country for:
# Department of GeriatricsThe 117th hospital of PLAHangzhou310013China.
# Can't find a country for:
# Department of Future TechnologiesUniversity of Turku20500TurkuFinland.
# Can't find a country for:
# State Key Laboratory of Fluid Power and Mechatronic Systems, College of Mechanical EngineeringZhejiang UniversityHangzhou310058China.
# Can't find a country for:
# Departments of Radiology (M.B., M.K., M.-Y.S., D.C.).
# Can't find a country for:
# Neurosurgery (G.C.).
# Can't find a country for:
# Departments of Radiology (M.B., M.K., M.-Y.S., D.C.).
# Can't find a country for:
# Neuro-Oncology (D.B.).
# Can't find a country for:
# Departments of Radiology (M.B., M.K., M.-Y.S., D.C.) chowd3@uci.edu.
# Can't find a country for:
# 4 Department of Biostatistics, and.
# Can't find a country for:
# Polytechnique School of PernambucoUniversity of PernambucoRecife-Pernambuco50720-001Brazil.
# Can't find a country for:
# Polytechnic School of PernambucoUniversity of PernambucoRecife-Pernambuco50100-010Brazil.
# Can't find a country for:
# Ecole Centrale MarseilleInstitut Fresnel UMR-CNRS 724913013MarseilleFrance.
# Can't find a country for:
# Department of Industrial and Systems Engineering, College of Engineering, UF.
# Can't find a country for:
# Department of Health Outcomes and Policy, UF.
# Can't find a country for:
# Department of Surgery, College of Medicine, UF.
# Can't find a country for:
# Department of Computer and Information Science and Engineering, College of Engineering, UF.
# Can't find a country for:
# Department of Health Services Research, Management and Policy, UF.
# Can't find a country for:
# Department of Biomedical Engineering, College of Engineering, UF.
# Can't find a country for:
# Department of Electrical and Computer Engineering, College of Engineering, UF.
# Can't find a country for:
# Department of Industrial and Systems Engineering, College of Engineering, UF.
# Can't find a country for:
# 4Department of Clinical Neurophysiology.
# Can't find a country for:
# Electronic and Electrical Engineering, Centre for Computational Imaging and Simulation Technologies in Biomedicine (CISTIB).
# Can't find a country for:
# Electronic and Electrical Engineering, Centre for Computational Imaging and Simulation Technologies in Biomedicine (CISTIB).
# Can't find a country for:
# 4Merck Research Laboratories,North Wales,Pennsylvania.
# Can't find a country for:
# 5Merck Vaccines,West Point,Pennsylvania.
# Can't find a country for:
# 4Merck Research Laboratories,North Wales,Pennsylvania.
# Can't find a country for:
# Department of Medical Biophysics.
# Can't find a country for:
# Department of Medical Biophysics.
# Can't find a country for:
# Department of Medical Biophysics.
# Can't find a country for:
# CPL Associates LLC.
# Can't find a country for:
# Department of Computer Science, UCL.
# Can't find a country for:
# Institute of Health Informatics, UCL.
# Can't find a country for:
# Institute of Cardiovascular Sciences, UCL.
# Can't find a country for:
# Institute of Health Informatics, UCL.
# Can't find a country for:
# Center for Learning and Experimental Psychopathology.
# Can't find a country for:
# Departments of Otolaryngology (D.L.).
# Can't find a country for:
# Statistics, Global Innovative Pharma.
# Can't find a country for:
# Division of Learning and Knowledge Systems, Department of Learning Health Sciences and kdpsingh@umich.edu.
# Can't find a country for:
# Division of Vascular Surgery, Stanford Health Care, Stanford, Calif. Electronic address: nleeper@stanford.edu.
# Can't find a country for:
# Psychology (M.L.C.).
# Can't find a country for:
# MIT Computer Science And Artificial Intelligence Laboratory, Tel.: +1-617-800-3033, souillardmandar@csail.mit.edu.
# Can't find a country for:
# MIT Computer Science And Artificial Intelligence Laboratory, Tel.: +1-617-253-5879, davis@csail.mit.edu.
# Can't find a country for:
# MIT Computer Science And Artificial Intelligence Laboratory, rudin@mit.edu.
# Error parsing Department of Pathology and Laboratory Medicine, Schulich School of Medicine and Dentistry, University of Western Ontario., trying again for a maximum of 5 times.
# Error parsing Department of Pathology and Laboratory Medicine, Schulich School of Medicine and Dentistry, University of Western Ontario., trying again for a maximum of 5 times.
# Can't find a country for:
# Intermountain Healthcare Cardiovascular Clinical Program.
# Can't find a country for:
# Intermountain Healthcare Cardiovascular Clinical Program.
# Can't find a country for:
# McKay Dee Hospital Cardiovascular Program.
# Can't find a country for:
# Computer Science and Artificial Intelligence Lab, EECS, MIT.
# Can't find a country for:
# Computer Science and Artificial Intelligence Lab, EECS, MIT.
# Can't find a country for:
# Graduate Institute of Biomedical Informatics.
# Can't find a country for:
# Departments of Biomedical Informatics, and michael.w.temple@vanderbilt.edu mtemple1@me.com.
# Can't find a country for:
# Australian e-Health Research Centre, CSIRO, Digital Productivity Flagship.
# Can't find a country for:
# Institute for Neural Computation, and.
# Can't find a country for:
# Center for the Study of Movement, Department of Neurology, Cognition and Mobility and jhausdor@tlvmc.gov.il.
# Can't find a country for:
# Electronics and Communication Sciences Unit, Indian Statistical Institute, Calcutta 700108 and.
# Can't find a country for:
# Electronics and Communication Sciences Unit, Indian Statistical Institute, Calcutta 700108 and.
# Can't find a country for:
# Carl.Berdahl@verizon.net
# Can't find a country for:
# Bio-IT Center, NEC Corporation. rteramotjp@gmail.com
# 100%|██████████████████████████████████████████████████████████████████████████| 42307/42307 [7:00:40<00:00,  1.68it/s]

# %%
articles.sample(25)
# Out:
#             pmid                                         doi  \
# 52691   33191075             10.1016/j.euroneuro.2020.11.009
# 25961   34364092                 10.1016/j.sleep.2021.07.023
# 166735  18819544                                         NaN
# 106874  29643160                 10.1136/bmjopen-2017-020124
# 47395   33432267                  10.1007/s11760-020-01820-2
# 58278   32941514                10.1371/journal.pone.0239071
# 73789   32078557                   10.1109/TCBB.2020.2973978
# 72138   32178296                           10.3390/s20061579
# 26186   34354361                        10.2147/JMDH.S322431
# 57095   33001400                  10.1007/s10877-020-00598-5
# 191222  10560504                                         NaN
# 123538  27208522                                         NaN
# 172413  17679338                                         NaN
# 34509   34022582  10.1016/j.jstrokecerebrovasdis.2021.105856
# 118973  28074090                        10.1155/2016/3891253
# 47367   33434133                  10.1109/TNSRE.2021.3051093
# 59350   32883362                  10.1186/s41065-020-00152-y
# 2745    35204339                 10.3390/diagnostics12020248
# 44181   33588254                  10.1016/j.cmpb.2021.105948
# 5520    35099027                   10.14744/tjtes.2020.06944
# 129947  26140956                                         NaN
# 106569  29677216                10.1371/journal.pone.0195318
# 82334   31586211                       10.1093/neuros/nyz403
# 119236  28035657                            10.1002/mp.12071
# 93379   30855231                               10.2196/11990
#
#                                                     title  \
# 52691   Higher baseline interleukin-1β and TNF-α hampe...
# 25961   Digital phenotyping of sleep patterns among he...
# 166735  Assessment of gastric cancer survival: using a...
# 106874  Using machine learning techniques to develop f...
# 47395   Evaluation of deep learning-based approaches f...
# 58278   Association between metabolic risk factors and...
# 73789   Cross-Domain Classification Model With Knowled...
# 72138   Automatic Detection of Arrhythmia Based on Mul...
# 26186   Early Prediction of COVID-19 Ventilation Requi...
# 57095   A mathematical model for predicting intracrani...
# 191222  Automated identification of tubercle bacilli i...
# 123538  Automated anterior segment OCT image analysis ...
# 172413  A concentric morphology model for the detectio...
# 34509   Prediction of Motor Function in Stroke Patient...
# 118973  Application of Machine Learning in Postural Co...
# 47367   Deep Learning for Accelerometric Data Assessme...
# 59350   A seven-gene signature model predicts overall ...
# 2745    An Efficient Multi-Level Convolutional Neural ...
# 44181   Arrhythmia classification from single-lead ECG...
# 5520    Use of deep learning methods for hand fracture...
# 129947  Machine Learning Approach to Optimizing Combin...
# 106569  Plasma metabolomic biomarkers accurately class...
# 82334   An Online Calculator for the Prediction of Sur...
# 119236  A computer-aided diagnostic system for detecti...
# 93379   Detecting Hypoglycemia Incidents Reported in P...
#
#                                                  abstract article_date  \
# 52691   Raised pro-inflammatory immune/inflammatory se...   2020-11-13
# 25961   This study aimed to identify sleep disturbance...   2021-07-19
# 166735  This study is designed to assess the applicati...          NaN
# 106874  Mortality and morbidity following surgery are ...   2018-04-10
# 47395   The COVID-19, novel coronavirus or SARS-Cov-2,...   2021-01-07
# 58278   This study aims to investigate correlation bet...   2020-09-17
# 73789   Conventional classification models for epilept...   2021-02-03
# 72138   Automatic detection of arrhythmia is of great ...   2020-03-12
# 26186   Coronavirus disease 2019 (COVID-19), caused by...   2021-07-30
# 57095   To develop and validate a mathematical model f...   2020-10-01
# 191222  To use an automated method to detect tubercle ...          NaN
# 123538  Angle closure glaucoma (ACG) is an eye disease...   2016-03-21
# 172413  We propose a technique for the automated detec...          NaN
# 34509   Machine learning (ML) techniques are being inc...   2021-05-19
# 118973  The use of wearable devices to study gait and ...   2016-12-18
# 47367   Ataxic gait monitoring and assessment of neuro...   2021-03-02
# 59350   Kidney renal clear cell carcinoma (KIRC) is a ...   2020-09-03
# 2745    The evaluation of white blood cells is essenti...   2022-01-20
# 44181   Arrhythmia is a heart disease characterized by...   2021-01-26
# 5520    Patients with hand trauma are usually examined...          NaN
# 129947  Deep brain stimulation (DBS) of the subthalami...   2015-06-15
# 106569  Past and recent attempts at devising objective...   2018-04-20
# 82334   Although survival statistics in patients with ...          NaN
# 119236  Detection (diagnosis) of diabetic retinopathy ...          NaN
# 93379   Improper dosing of medications such as insulin...   2019-03-11
#
#        pubmed_date      article_type lang  \
# 52691   2020-11-17   Journal Article  eng
# 25961   2021-08-08   Journal Article  eng
# 166735  2008-09-30   Journal Article  eng
# 106874  2018-04-13   Journal Article  eng
# 47395   2021-01-13   Journal Article  eng
# 58278   2020-09-18   Journal Article  eng
# 73789   2020-02-23   Journal Article  eng
# 72138   2020-03-18   Journal Article  eng
# 26186   2021-08-07   Journal Article  eng
# 57095   2020-10-02   Journal Article  eng
# 191222  1999-11-24   Journal Article  eng
# 123538  2016-05-22   Journal Article  eng
# 172413  2007-08-08  Evaluation Study  eng
# 34509   2021-05-23   Journal Article  eng
# 118973  2017-01-12   Journal Article  eng
# 47367   2021-01-13   Journal Article  eng
# 59350   2020-09-05   Journal Article  eng
# 2745    2022-02-26   Journal Article  eng
# 44181   2021-02-16   Journal Article  eng
# 5520    2022-02-01   Journal Article  eng
# 129947  2015-07-05   Journal Article  eng
# 106569  2018-04-21   Journal Article  eng
# 82334   2019-10-06   Journal Article  eng
# 119236  2016-12-31   Journal Article  eng
# 93379   2019-03-12   Journal Article  eng
#
#                                                   journal  \
# 52691   European neuropsychopharmacology : the journal...
# 25961                                      Sleep medicine
# 166735     Pakistan journal of biological sciences : PJBS
# 106874                                           BMJ open
# 47395                  Signal, image and video processing
# 58278                                            PloS one
# 73789   IEEE/ACM transactions on computational biology...
# 72138                        Sensors (Basel, Switzerland)
# 26186             Journal of multidisciplinary healthcare
# 57095        Journal of clinical monitoring and computing
# 191222  Analytical and quantitative cytology and histo...
# 123538       Computer methods and programs in biomedicine
# 172413               IEEE transactions on medical imaging
# 34509   Journal of stroke and cerebrovascular diseases...
# 118973        Computational intelligence and neuroscience
# 47367   IEEE transactions on neural systems and rehabi...
# 59350                                           Hereditas
# 2745                     Diagnostics (Basel, Switzerland)
# 44181        Computer methods and programs in biomedicine
# 5520    Ulusal travma ve acil cerrahi dergisi = Turkis...
# 129947                                  Brain stimulation
# 106569                                           PloS one
# 82334                                        Neurosurgery
# 119236                                    Medical physics
# 93379                Journal of medical Internet research
#
#                                journal_short  ... subspec_arrhyt spec_dm  \
# 52691               Eur Neuropsychopharmacol  ...            0.0     0.0
# 25961                              Sleep Med  ...            0.0     0.0
# 166735                        Pak J Biol Sci  ...            0.0     0.0
# 106874                              BMJ Open  ...            0.0     0.0
# 47395             Signal Image Video Process  ...            0.0     0.0
# 58278                               PLoS One  ...            0.0     1.0
# 73789   IEEE/ACM Trans Comput Biol Bioinform  ...            0.0     0.0
# 72138                        Sensors (Basel)  ...            1.0     0.0
# 26186                  J Multidiscip Healthc  ...            0.0     0.0
# 57095                    J Clin Monit Comput  ...            0.0     0.0
# 191222               Anal Quant Cytol Histol  ...            0.0     0.0
# 123538        Comput Methods Programs Biomed  ...            0.0     0.0
# 172413                IEEE Trans Med Imaging  ...            0.0     0.0
# 34509               J Stroke Cerebrovasc Dis  ...            0.0     0.0
# 118973                Comput Intell Neurosci  ...            0.0     0.0
# 47367     IEEE Trans Neural Syst Rehabil Eng  ...            0.0     0.0
# 59350                              Hereditas  ...            0.0     0.0
# 2745                     Diagnostics (Basel)  ...            0.0     0.0
# 44181         Comput Methods Programs Biomed  ...            1.0     0.0
# 5520           Ulus Travma Acil Cerrahi Derg  ...            0.0     0.0
# 129947                          Brain Stimul  ...            0.0     0.0
# 106569                              PLoS One  ...            0.0     0.0
# 82334                           Neurosurgery  ...            0.0     0.0
# 119236                              Med Phys  ...            0.0     1.0
# 93379                     J Med Internet Res  ...            0.0     1.0
#
#        subspec_retina spec_haem spec_obs spec_renal  \
# 52691             0.0       0.0      0.0        0.0
# 25961             0.0       0.0      0.0        0.0
# 166735            0.0       0.0      0.0        0.0
# 106874            0.0       0.0      0.0        1.0
# 47395             0.0       0.0      0.0        0.0
# 58278             1.0       0.0      0.0        0.0
# 73789             0.0       0.0      0.0        0.0
# 72138             0.0       0.0      0.0        0.0
# 26186             0.0       0.0      0.0        0.0
# 57095             0.0       0.0      0.0        0.0
# 191222            0.0       0.0      0.0        0.0
# 123538            0.0       0.0      0.0        0.0
# 172413            0.0       0.0      0.0        0.0
# 34509             0.0       0.0      0.0        0.0
# 118973            0.0       0.0      0.0        0.0
# 47367             0.0       0.0      0.0        0.0
# 59350             0.0       0.0      0.0        1.0
# 2745              0.0       0.0      0.0        0.0
# 44181             0.0       0.0      0.0        0.0
# 5520              0.0       0.0      0.0        0.0
# 129947            0.0       0.0      0.0        0.0
# 106569            0.0       0.0      0.0        0.0
# 82334             0.0       0.0      0.0        0.0
# 119236            1.0       0.0      0.0        0.0
# 93379             0.0       0.0      0.0        0.0
#
#                                           affil_countries  \
# 52691   ['Italy', 'Italy', 'Italy', 'Italy', 'Italy', ...
# 25961   ['United States', 'United States', 'United Sta...
# 166735                                              [nan]
# 106874  ['United States', 'United States', 'United Sta...
# 47395                ['China', 'China', 'China', 'China']
# 58278   ['South Korea', 'South Korea', 'South Korea', ...
# 73789                                               [nan]
# 72138       ['China', 'China', 'China', 'China', 'China']
# 26186   ['Saudi Arabia', 'Saudi Arabia', 'Saudi Arabia...
# 57095   ['China', 'China', 'China', 'China', 'United S...
# 191222                                              [nan]
# 123538  ['Singapore', 'Singapore', 'China', 'Singapore...
# 172413                                              [nan]
# 34509       ['South Korea', 'South Korea', 'South Korea']
# 118973  ['Portugal', 'Portugal', 'Portugal', 'Portugal...
# 47367                                               [nan]
# 59350       ['China', 'China', 'China', 'China', 'China']
# 2745        ['Chile', 'Chile', 'Chile', 'Chile', 'Chile']
# 44181   ['Brazil', 'Brazil', 'Brazil', 'Brazil', 'Unit...
# 5520    ['Turkey', 'Turkey', 'Turkey', 'Turkey', 'Turk...
# 129947  ['United States', 'United States', 'United Sta...
# 106569  ['United States', 'United States', 'United Sta...
# 82334   ['United States', 'United States', 'Canada', '...
# 119236  ['Egypt', 'United States', 'United States', 'U...
# 93379   ['United States', 'United States', 'United Sta...
#
#                               affil_countries_unique  affil_first_country  \
# 52691                                      ['Italy']                Italy
# 25961                              ['United States']        United States
# 166735                                         [nan]                  NaN
# 106874                             ['United States']        United States
# 47395                                      ['China']                China
# 58278                                ['South Korea']          South Korea
# 73789                                          [nan]                  NaN
# 72138                                      ['China']                China
# 26186                               ['Saudi Arabia']         Saudi Arabia
# 57095   ['United Kingdom', 'United States', 'China']                China
# 191222                                         [nan]                  NaN
# 123538       ['United States', 'China', 'Singapore']            Singapore
# 172413                                         [nan]                  NaN
# 34509                                ['South Korea']          South Korea
# 118973                                  ['Portugal']             Portugal
# 47367                                          [nan]                  NaN
# 59350                                      ['China']                China
# 2745                                       ['Chile']                Chile
# 44181                    ['United States', 'Brazil']               Brazil
# 5520                                      ['Turkey']               Turkey
# 129947                             ['United States']        United States
# 106569                             ['United States']        United States
# 82334     ['Netherlands', 'Canada', 'United States']        United States
# 119236     ['New Zealand', 'United States', 'Egypt']                Egypt
# 93379                              ['United States']        United States
#
#         affil_last_country
# 52691                Italy
# 25961        United States
# 166735                 NaN
# 106874       United States
# 47395                China
# 58278          South Korea
# 73789                  NaN
# 72138                China
# 26186         Saudi Arabia
# 57095       United Kingdom
# 191222                 NaN
# 123538           Singapore
# 172413                 NaN
# 34509          South Korea
# 118973            Portugal
# 47367                  NaN
# 59350                China
# 2745                 Chile
# 44181               Brazil
# 5520                Turkey
# 129947       United States
# 106569       United States
# 82334        United States
# 119236               Egypt
# 93379        United States
#
# [25 rows x 80 columns]

# %%
#articles.to_csv('data/final_raw.csv')

# %%
articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42307 entries, 1 to 192947
# Data columns (total 80 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pmid                    42307 non-null  int64
#  1   doi                     37409 non-null  object
#  2   title                   42306 non-null  object
#  3   abstract                42307 non-null  object
#  4   article_date            32669 non-null  object
#  5   pubmed_date             42307 non-null  object
#  6   article_type            42307 non-null  object
#  7   lang                    42307 non-null  object
#  8   journal                 42307 non-null  object
#  9   journal_short           42307 non-null  object
#  10  journal_country         42307 non-null  object
#  11  authors                 41281 non-null  object
#  12  author_affils           31156 non-null  object
#  13  keywords                24364 non-null  object
#  14  mesh_terms              32535 non-null  object
#  15  references_pmids        21512 non-null  object
#  16  feature                 42307 non-null  object
#  17  year                    42307 non-null  int64
#  18  include                 42307 non-null  float64
#  19  mature                  42307 non-null  float64
#  20  algo_neural_net         42307 non-null  float64
#  21  algo_support_vector     42307 non-null  float64
#  22  algo_regression         42307 non-null  float64
#  23  algo_decision_tree      42307 non-null  float64
#  24  feat_xr                 42307 non-null  float64
#  25  feat_ct                 42307 non-null  float64
#  26  feat_mri                42307 non-null  float64
#  27  feat_eeg                42307 non-null  float64
#  28  feat_ecg                42307 non-null  float64
#  29  feat_emg                42307 non-null  float64
#  30  feat_us                 42307 non-null  float64
#  31  feat_echo               42307 non-null  float64
#  32  feat_histo              42307 non-null  float64
#  33  feat_oct                42307 non-null  float64
#  34  feat_mamm               42307 non-null  float64
#  35  feat_endoscop           42307 non-null  float64
#  36  feat_gene               42307 non-null  float64
#  37  feat_bio                42307 non-null  float64
#  38  feat_nlp                42307 non-null  float64
#  39  feat_ehr                42307 non-null  float64
#  40  subspec_icu             42307 non-null  float64
#  41  subspec_ed              42307 non-null  float64
#  42  spec_paeds              42307 non-null  float64
#  43  spec_id                 42307 non-null  float64
#  44  subspec_sepsis          42307 non-null  float64
#  45  subspec_cov19           42307 non-null  float64
#  46  subspec_dermca          42307 non-null  float64
#  47  spec_onc                42307 non-null  float64
#  48  subspec_lungca          42307 non-null  float64
#  49  subspec_brainca         42307 non-null  float64
#  50  subspec_gica            42307 non-null  float64
#  51  subspec_hepca           42307 non-null  float64
#  52  subspec_prosca          42307 non-null  float64
#  53  subspec_gynonc          42307 non-null  float64
#  54  subspec_haemonc         42307 non-null  float64
#  55  subspec_breastca        42307 non-null  float64
#  56  subspec_urology         42307 non-null  float64
#  57  spec_psych              42307 non-null  float64
#  58  spec_msk                42307 non-null  float64
#  59  spec_gi                 42307 non-null  float64
#  60  spec_hep                42307 non-null  float64
#  61  spec_resp               42307 non-null  float64
#  62  subspec_pneum           42307 non-null  float64
#  63  spec_neuro              42307 non-null  float64
#  64  subspec_epilep          42307 non-null  float64
#  65  subspec_cva             42307 non-null  float64
#  66  subspec_alzh            42307 non-null  float64
#  67  spec_cvs                42307 non-null  float64
#  68  subspec_ihd             42307 non-null  float64
#  69  subspec_hf              42307 non-null  float64
#  70  subspec_arrhyt          42307 non-null  float64
#  71  spec_dm                 42307 non-null  float64
#  72  subspec_retina          42307 non-null  float64
#  73  spec_haem               42307 non-null  float64
#  74  spec_obs                42307 non-null  float64
#  75  spec_renal              42307 non-null  float64
#  76  affil_countries         42019 non-null  object
#  77  affil_countries_unique  42019 non-null  object
#  78  affil_first_country     30788 non-null  object
#  79  affil_last_country      30779 non-null  object
# dtypes: float64(58), int64(2), object(20)
# memory usage: 27.2+ MB

# %% [markdown]
# ## CLEAN

# %%
articles['affil_fill_country'] = articles['affil_first_country']

# %%
## using first affiliation as primary country
## fill first with data from last author, then with pubmed country metadata
articles['affil_fill_country'] = articles['affil_fill_country'].fillna(articles['affil_last_country'])
articles['affil_fill_country'] = articles['affil_fill_country'].fillna(articles['journal_country'])

articles['affil_fill_country'] = articles['affil_fill_country'].astype('string')

# %%
##clean countries
articles["affil_fill_country"].replace({"England": "United Kingdom", 
                                             "Wales": "United Kingdom", 
                                             "Scotland": "United Kingdom", 
                                             "China (Republic : 1949- )" : "Taiwan"}, inplace=True)

articles['affil_fill_country'].value_counts()
# Out:
# United States          14664
# China                   7107
# United Kingdom          2903
# South Korea             1651
# Germany                 1567
#                        ...
# Trinidad and Tobago        1
# Belarus                    1
# Cameroon                   1
# Kazakhstan                 1
# Palestine                  1
# Name: affil_fill_country, Length: 97, dtype: int64

# %%
articles['affil_first_country'] = articles['affil_first_country'].fillna(articles['affil_last_country'])

articles["affil_first_country"].replace({"England": "United Kingdom", 
                                             "Wales": "United Kingdom", 
                                             "Scotland": "United Kingdom", 
                                             "China (Republic : 1949- )" : "Taiwan"}, inplace=True)

# %%
articles['affil_first_country'].value_counts()
# Out:
# United States          6983
# China                  6911
# South Korea            1651
# United Kingdom         1262
# India                  1207
#                        ...
# Belarus                   1
# Trinidad and Tobago       1
# Kazakhstan                1
# Cameroon                  1
# Palestine                 1
# Name: affil_first_country, Length: 93, dtype: int64

# %%
##lowercasing list of ANY author
articles['countries_lc'] = articles['affil_countries_unique'].str.lower().fillna(np.nan)

#articles['countries_lc'] = articles['countries_lc'].fillna(articles['affil_fill_country']).str.lower().astype('string')

# %%
articles['countries_lc'].replace(np.nan, '', inplace=True)

# %%
lmic_list = ["afghanistan", "burundi", "burkina faso", "central african republic", "congo", "eritrea", 
             "ethiopia", "guinea", "gambia", "guinea-bissau", "liberia", "madagascar", "mali", "mozambique", "malawi", 
             "niger", "north korea", "democratic republic of korea", "rwanda", "sudan", "sierra leone", "somalia", "south sudan", "syrian arab republic", 
             "chad", "togo", "uganda", "yemen", "angola", "benin", "bangladesh", "belize", "bolivia", "bhutan", 
             "cote d'ivoire", "ivory coast", "cameroon", "congo", "comoros", "cabo verde", "djibouti", "algeria", "egypt", 
             "micronesia", "ghana", "honduras", "haiti", "indonesia", "india", "iran", "kenya", 
             "kyrgyz republic", "cambodia", "kiribati", "lao", "sri lanka", "lesotho", "morocco", "myanmar", "mongolia", 
             "mauritania", "nigeria", "nicaragua", "nepal", "pakistan", "philippines", "papua new guinea", 
             "west bank and gaza", "palestinbe", "senegal", "solomon islands", "el salvador", "sao tome", "eswatini", 
             "tajikistan", "timor-leste", "tunisia", "tanzania", "ukraine", "uzbekistan", "vietnam", "vanuatu", "samoa", 
             "zambia", "zimbabwe", "albania", "argentina", "armenia", "american samoa", "azerbaijan", "bulgaria", 
             "bosnia", "belarus", "brazil", "botswana", "china", "colombia", "costa rica", "cuba", 
             "dominica", "dominican republic", "ecuador", "fiji", "gabon", "georgia", "equatorial guinea", "grenada", 
             "guatemala", "guyana", "iraq", "jamaica", "jordan", "kazakhstan", "lebanon", "libya", "lucia", "moldova", 
             "maldives", "mexico", "marshall islands", "north macedonia", "montenegro", "mauritius", "malaysia", "namibia", 
             "panama", "peru", "paraguay", "romania", "russian federation", "russia", "serbia", "suriname", "thailand", "turkmenistan", 
             "tonga", "turkey", "tuvalu", "st. vincent", "grenadines", "kosovo", "south africa", "venezuela"]

# %%
lmic_lower_list = ["afghanistan", "burundi", "burkina faso", "central african republic", "congo", "eritrea", 
             "ethiopia", "guinea", "gambia", "guinea-bissau", "liberia", "madagascar", "mali", "mozambique", "malawi", 
             "niger", "north korea", "democratic republic of korea", "rwanda", "sudan", 'iran', "sierra leone", "somalia", "south sudan", "syrian arab republic", 
             "chad", "togo", "uganda", "yemen", "angola", "benin", "bangladesh", "belize", "bolivia", "bhutan", 
             "cote d'ivoire", "ivory coast", "cameroon", "congo", "comoros", "cabo verde", "djibouti", "algeria", "egypt", 
             "micronesia", "ghana", "honduras", "haiti", "indonesia", "india", "kenya", 
             "kyrgyz republic", "cambodia", "kiribati", "lao", "sri lanka", "lesotho", "morocco", "myanmar", "mongolia", 
             "mauritania", "nigeria", "nicaragua", "nepal", "pakistan", "philippines", "papua new guinea", 
             "west bank and gaza", "palestinbe", "senegal", "solomon islands", "el salvador", "sao tome", "eswatini", 
             "tajikistan", "timor-leste", "tunisia", "tanzania", "ukraine", "uzbekistan", "vietnam", "vanuatu", "samoa", 
             "zambia", "zimbabwe"]

# %%
##flags for ANY author

#initiate
articles['lmic_author_flag'] = np.where(articles['countries_lc'].str.contains('iran'), "1", "0")
articles['lmic_author_lower_flag'] = np.where(articles['countries_lc'].str.contains('iran'), "1", "0")
articles['lmic_china_flag'] = np.where(articles['countries_lc'].str.contains('china'), "1", "0")

# %%
#use lists
for x in lmic_list:
    articles['lmic_author_flag'] = np.where(articles['countries_lc'].str.contains(x), "1", articles['lmic_author_flag'])
    
for y in lmic_lower_list:
    articles['lmic_author_lower_flag'] = np.where(articles['countries_lc'].str.contains(x), "1", articles['lmic_author_lower_flag'])

# %%
articles['pubmed_date'] = pd.to_datetime(articles['pubmed_date'])

# %%
## new column for year, and year+month
articles['year'] = articles['pubmed_date'].dt.year

# %%
articles['lmic_author_lower_flag'].value_counts()
# Out:
# 0    41739
# 1      568
# Name: lmic_author_lower_flag, dtype: int64

# %%
articles.to_csv('data/final_raw.csv')

# %%
articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42307 entries, 1 to 192947
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pmid                    42307 non-null  int64
#  1   doi                     37409 non-null  object
#  2   title                   42306 non-null  object
#  3   abstract                42307 non-null  object
#  4   article_date            32669 non-null  object
#  5   pubmed_date             42307 non-null  datetime64[ns]
#  6   article_type            42307 non-null  object
#  7   lang                    42307 non-null  object
#  8   journal                 42307 non-null  object
#  9   journal_short           42307 non-null  object
#  10  journal_country         42307 non-null  object
#  11  authors                 41281 non-null  object
#  12  author_affils           31156 non-null  object
#  13  keywords                24364 non-null  object
#  14  mesh_terms              32535 non-null  object
#  15  references_pmids        21512 non-null  object
#  16  feature                 42307 non-null  object
#  17  year                    42307 non-null  int64
#  18  include                 42307 non-null  float64
#  19  mature                  42307 non-null  float64
#  20  algo_neural_net         42307 non-null  float64
#  21  algo_support_vector     42307 non-null  float64
#  22  algo_regression         42307 non-null  float64
#  23  algo_decision_tree      42307 non-null  float64
#  24  feat_xr                 42307 non-null  float64
#  25  feat_ct                 42307 non-null  float64
#  26  feat_mri                42307 non-null  float64
#  27  feat_eeg                42307 non-null  float64
#  28  feat_ecg                42307 non-null  float64
#  29  feat_emg                42307 non-null  float64
#  30  feat_us                 42307 non-null  float64
#  31  feat_echo               42307 non-null  float64
#  32  feat_histo              42307 non-null  float64
#  33  feat_oct                42307 non-null  float64
#  34  feat_mamm               42307 non-null  float64
#  35  feat_endoscop           42307 non-null  float64
#  36  feat_gene               42307 non-null  float64
#  37  feat_bio                42307 non-null  float64
#  38  feat_nlp                42307 non-null  float64
#  39  feat_ehr                42307 non-null  float64
#  40  subspec_icu             42307 non-null  float64
#  41  subspec_ed              42307 non-null  float64
#  42  spec_paeds              42307 non-null  float64
#  43  spec_id                 42307 non-null  float64
#  44  subspec_sepsis          42307 non-null  float64
#  45  subspec_cov19           42307 non-null  float64
#  46  subspec_dermca          42307 non-null  float64
#  47  spec_onc                42307 non-null  float64
#  48  subspec_lungca          42307 non-null  float64
#  49  subspec_brainca         42307 non-null  float64
#  50  subspec_gica            42307 non-null  float64
#  51  subspec_hepca           42307 non-null  float64
#  52  subspec_prosca          42307 non-null  float64
#  53  subspec_gynonc          42307 non-null  float64
#  54  subspec_haemonc         42307 non-null  float64
#  55  subspec_breastca        42307 non-null  float64
#  56  subspec_urology         42307 non-null  float64
#  57  spec_psych              42307 non-null  float64
#  58  spec_msk                42307 non-null  float64
#  59  spec_gi                 42307 non-null  float64
#  60  spec_hep                42307 non-null  float64
#  61  spec_resp               42307 non-null  float64
#  62  subspec_pneum           42307 non-null  float64
#  63  spec_neuro              42307 non-null  float64
#  64  subspec_epilep          42307 non-null  float64
#  65  subspec_cva             42307 non-null  float64
#  66  subspec_alzh            42307 non-null  float64
#  67  spec_cvs                42307 non-null  float64
#  68  subspec_ihd             42307 non-null  float64
#  69  subspec_hf              42307 non-null  float64
#  70  subspec_arrhyt          42307 non-null  float64
#  71  spec_dm                 42307 non-null  float64
#  72  subspec_retina          42307 non-null  float64
#  73  spec_haem               42307 non-null  float64
#  74  spec_obs                42307 non-null  float64
#  75  spec_renal              42307 non-null  float64
#  76  affil_countries         42019 non-null  object
#  77  affil_countries_unique  42019 non-null  object
#  78  affil_first_country     30811 non-null  object
#  79  affil_last_country      30779 non-null  object
#  80  affil_fill_country      42307 non-null  object
#  81  countries_lc            42307 non-null  object
#  82  lmic_author_flag        42307 non-null  object
#  83  lmic_author_lower_flag  42307 non-null  object
#  84  lmic_china_flag         42307 non-null  object
# dtypes: datetime64[ns](1), float64(58), int64(2), object(24)
# memory usage: 28.8+ MB

# %%
imported = pd.read_csv('data/included_abstracts_21032022.csv', index_col=0)
imported.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38912 entries, 0 to 38911
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pmid                    38912 non-null  int64
#  1   doi                     34248 non-null  object
#  2   title                   38911 non-null  object
#  3   abstract                38912 non-null  object
#  4   article_date            30193 non-null  object
#  5   pubmed_date             38912 non-null  object
#  6   article_type            38912 non-null  object
#  7   lang                    38912 non-null  object
#  8   journal                 38912 non-null  object
#  9   journal_short           38912 non-null  object
#  10  journal_country         38912 non-null  object
#  11  authors                 38016 non-null  object
#  12  author_affils           28554 non-null  object
#  13  keywords                22292 non-null  object
#  14  mesh_terms              25649 non-null  object
#  15  references_pmids        16872 non-null  object
#  16  include                 38912 non-null  int64
#  17  mature                  38912 non-null  int64
#  18  algo_neural_net         38912 non-null  float64
#  19  algo_support_vector     38912 non-null  float64
#  20  algo_regression         38912 non-null  float64
#  21  algo_decision_tree      38912 non-null  float64
#  22  feat_xr                 38912 non-null  float64
#  23  feat_ct                 38912 non-null  float64
#  24  feat_mri                38912 non-null  float64
#  25  feat_eeg                38912 non-null  float64
#  26  feat_ecg                38912 non-null  float64
#  27  feat_emg                38912 non-null  float64
#  28  feat_us                 38912 non-null  float64
#  29  feat_echo               38912 non-null  float64
#  30  feat_histo              38912 non-null  float64
#  31  feat_oct                38912 non-null  float64
#  32  feat_mamm               38912 non-null  float64
#  33  feat_endoscop           38912 non-null  float64
#  34  feat_gene               38912 non-null  float64
#  35  feat_bio                38912 non-null  float64
#  36  feat_nlp                38912 non-null  float64
#  37  feat_ehr                38912 non-null  float64
#  38  subspec_icu             38912 non-null  float64
#  39  subspec_ed              38912 non-null  float64
#  40  spec_paeds              38912 non-null  float64
#  41  spec_id                 38912 non-null  float64
#  42  subspec_sepsis          38912 non-null  float64
#  43  subspec_cov19           38912 non-null  float64
#  44  subspec_dermca          38912 non-null  float64
#  45  spec_onc                38912 non-null  float64
#  46  subspec_lungca          38912 non-null  float64
#  47  subspec_brainca         38912 non-null  float64
#  48  subspec_gica            38912 non-null  float64
#  49  subspec_hepca           38912 non-null  float64
#  50  subspec_prosca          38912 non-null  float64
#  51  subspec_gynonc          38912 non-null  float64
#  52  subspec_haemonc         38912 non-null  float64
#  53  subspec_breastca        38912 non-null  float64
#  54  subspec_urology         38912 non-null  float64
#  55  spec_psych              38912 non-null  float64
#  56  spec_msk                38912 non-null  float64
#  57  spec_gi                 38912 non-null  float64
#  58  spec_hep                38912 non-null  float64
#  59  spec_resp               38912 non-null  float64
#  60  subspec_pneum           38912 non-null  float64
#  61  spec_neuro              38912 non-null  float64
#  62  subspec_epilep          38912 non-null  float64
#  63  subspec_cva             38912 non-null  float64
#  64  subspec_alzh            38912 non-null  float64
#  65  spec_cvs                38912 non-null  float64
#  66  subspec_ihd             38912 non-null  float64
#  67  subspec_hf              38912 non-null  float64
#  68  subspec_arrhyt          38912 non-null  float64
#  69  spec_dm                 38912 non-null  float64
#  70  subspec_retina          38912 non-null  float64
#  71  spec_haem               38912 non-null  float64
#  72  spec_obs                38912 non-null  float64
#  73  spec_renal              38912 non-null  float64
#  74  affil_countries         28030 non-null  object
#  75  affil_countries_unique  27935 non-null  object
#  76  affil_first_country     27933 non-null  object
#  77  affil_last_country      27904 non-null  object
#  78  affil_fill_country      38912 non-null  object
#  79  countries_lc            27935 non-null  object
#  80  lmic_author_flag        38912 non-null  float64
#  81  lmic_author_lower_flag  38912 non-null  float64
#  82  lmic_china_flag         38912 non-null  float64
#  83  year                    38912 non-null  float64
# dtypes: float64(60), int64(3), object(21)
# memory usage: 25.2+ MB
